# %%
# !pip install openpyxl
import openpyxl
import os
import shutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r "/content/drive/My Drive/Indian Police MoRTH data set/missing_images" ./
# !cp -r "/content/drive/My Drive/Indian Police MoRTH data set/tbl_cr_missing_details.xlsx" ./

# %%
folders=['/A00_5F','/A00_5M','/A05_10F','/A05_10M','/A10_16F','/A10_16M','/A16_24F','/A16_24M','/A24_32F','/A24_32M','/A32_42F','/A32_42M','/A42_52F','/A42_52M','/A52_62F','/A52_62M','/A62_70F','/A62_70M','/A70_120F','/A70_120M']
dset='./police_db'
if(os.path.exists(dset)):
  print("File exists")  
else:
  os.mkdir(dset)
  print("File created.")

for j in folders:
 if(os.path.exists(dset+j)):
  print("File exists")  
 else:
  os.mkdir(dset+j)
  print("File created.")
# Out:
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.
# File created.

# %%
wb=openpyxl.load_workbook('./tbl_cr_missing_details.xlsx')
wb_obj=wb.active
#age column =13
#gender column =12
#img name = 26
#case number =27
for i in range(2,1001):
  if(i!=35):
    age = wb_obj.cell(row = i, column = 13).value
    gender=wb_obj.cell(row = i, column = 12).value
    name=wb_obj.cell(row = i, column = 26).value
    case=wb_obj.cell(row = i, column = 26).value
    if(gender=='Female'):
      gender=0
    else:
      gender=1;
    src='./missing_images/'+name
    print(i,age,gender)
    if(age in range(70,2000)):
      #print("hello")
    #  if(os.path.exists(src)):
    #   print("yes")
      if(gender==0):
          dst=dset+folders[18]+'/'+name 
          dest=dset+folders[18]+'/'
          if(os.path.exists(dst)):
            print("yes0")
          else:
          #print("moved")
            shutil.move(src,dest)
      if(gender==1):
          dst=dset+folders[19]+'/'+name
          dest=dset+folders[19]+'/'
          if(os.path.exists(dst)):
            print("yes1")
            #print(dst)
          else:
            shutil.move(src,dest)
# Out:
# 2 63 0
# 3 22 0
# 4 16 0
# 5 25 0
# 6 4 0
# 7 48 0
# 8 19 0
# 9 8 1
# 10 70 1
# 11 50 1
# 12 17 0
# 13 28 0
# 14 11 1
# 15 6 1
# 16 16 0
# 17 25 0
# 18 19 0
# 19 15 0
# 20 30 0
# 21 19 0
# 22 52 0
# 23 35 1
# 24 23 0
# 25 17 0
# 26 24 0
# 27 16 0
# 28 20 0
# 29 31 1
# 30 17 0
# 31 25 0
# 32 11 1
# 33 36 0
# 34 16 1
# 36 85 0
# 37 75 1
# 38 7 1
# 39 17 0
# 40 32 1
# 41 33 0
# 42 18 0
# 43 17 0
# 44 19 0
# 45 40 1
# 46 38 1
# 47 21 0
# 48 25 0
# 49 19 0
# 50 65 1
# 51 22 1
# 52 32 1
# 53 45 0
# 54 55 1
# 55 18 0
# 56 73 1
# 57 20 0
# 58 17 0
# 59 60 1
# 60 17 0
# 61 14 1
# 62 19 0
# 63 19 0
# 64 35 1
# 65 16 0
# 66 34 1
# 67 54 1
# 68 16 1
# 69 15 0
# 70 61 1
# 71 20 0
# 72 21 0
# 73 25 1
# 74 42 1
# 75 14 1
# 76 17 0
# 77 15 1
# 78 19 0
# 79 27 0
# 80 23 0
# 81 19 0
# 82 23 0
# 83 13 1
# 84 13 0
# 85 16 0
# 86 0 0
# 87 30 0
# 88 35 0
# 89 19 0
# 90 75 1
# 91 38 1
# 92 32 1
# 93 13 1
# 94 30 0
# 95 17 0
# 96 19 0
# 97 65 1
# 98 18 0
# 99 24 0
# 100 54 1
# 101 19 0
# 102 4 1
# 103 31 0
# ...

# %%
"""
for i in os.listdir("./missing_images"):
  #print(i)
  if i =='IMG_201809#_e85ec78f-503c-4c26-8bce-1743de71d6f2699.jpg':
    print(type(i))
    print("yes")
    x=os.path.join("./missing_images/",i)
    shutil.move(x,'./')

"""

# %%
count=0
for i in os.listdir('./police_db'):
  for j in os.listdir('./police_db/'+i):
    count=count+1
print(count)
# Out:
# 995

# %%
# !zip -r ./police_db.zip ./police_db
# !cp "police_db.zip" "/content/drive/My Drive/Research Project/police_db.zip"
# Out:
#   adding: police_db/ (stored 0%)
#   adding: police_db/A70_120M/ (stored 0%)
#   adding: police_db/A70_120M/pp#_c0d4a44d-3d33-48f9-8127-5b74aece35251340.jpg (deflated 7%)
#   adding: police_db/A70_120M/559#_68f6d52c-5d0d-494c-8120-93964ab9f48d858.jpg (deflated 3%)
#   adding: police_db/A70_120M/IMG_201809#_6eb4989f-08a6-407b-8950-1903d494b8b5334.jpg (deflated 15%)
#   adding: police_db/A70_120M/IMG_000100#_48ad7c0a-c477-414e-bb24-d1835f4cac2c1570.jpg (deflated 24%)
#   adding: police_db/A70_120M/301#_946a2fd4-6268-418e-acde-6ce39a91e4511426.jpg (deflated 1%)
#   adding: police_db/A70_120M/Photo#_cea6de2b-e36b-454a-a5f1-2ae26c6f64f1351.jpg (deflated 18%)
#   adding: police_db/A70_120M/Cr No 145-#_b5abb0c0-8e2f-440c-a962-e7c038ce4add1503.jpg (deflated 23%)
#   adding: police_db/A70_120M/PHOTO 232-#_36e96444-1b4c-46ea-b468-2217af6ef4d0748.jpg (deflated 52%)
#   adding: police_db/A70_120M/478-18#_71a64d07-aa95-4628-a098-3da28c6766b71414.jpg (deflated 6%)
# ...
